# %% [markdown]
# # Mad Libs Python Project
# #### For this project i will be creating a Mad_libs story for this project. This project is a low level python project that exhibits my basic understanding of python

# %%
# Define function needed to get user input
def get_input(word_type: str):
    user_input: str = input(f'Enter a {word_type}: ')
    return user_input

# Define the nouns, verbs, adjectives, and adverbs needed for the story
noun1 = get_input('noun')
verb1 = get_input('verb')
noun2 = get_input('noun')
verb2 = get_input('verb')
adjective1 = get_input('adjective')
adjective2 = get_input('adjective')
noun3 = get_input('noun')
verb3 = get_input('verb')
adjective3 = get_input('adjective')
place = get_input('place')
# pronouns1 = get_input('pronouns')
# pronouns2 = get_input('pronouns')
# pronouns3 = get_input('pronouns')


# User Story 
user_story = f"""

Once upon a time, in a quaint little village, there lived a {adjective1} {noun1} named {get_input('name')}. 

{get_input('pronoun').capitalize()} was known for {verb1}ing with unmatched enthusiasm, spreading joy and laughter to everyone {get_input('pronoun')} met.

One sunny day, as {get_input('name')} {verb1}ed through the {get_input('nature')} {get_input('place_type')}, {get_input('pronoun').capitalize()} encountered a mysterious {adjective2} {noun2}. 

This {noun2}, named {get_input('name')}, had the ability to {verb2} with a magical touch. Intrigued, {get_input('name')} decided to {verb2} alongside {get_input('name')}.

As they {verb2}ed together, they stumbled upon an ancient {noun3} hidden in the heart of the {get_input('place_type')}. 

Legend had it that this {noun3} held the key to unlocking {adjective3} powers. With determination in their hearts, 

{get_input('name')} and {get_input('name')} embarked on a quest to unravel the mysteries of the {noun3}.

Their journey took them through enchanted forests, across vast deserts, and over towering mountains. 

Along the way, they encountered a wise old {noun1} who {verb1}ed ancient tales of bravery and friendship. 

Inspired by these stories, {get_input('name')} and {get_input('name')} continued their quest with renewed vigor.

One day, as they reached the summit of the highest mountain, they discovered the {noun3}'s secret – it held the power to make {verb3} come true. 

Overwhelmed with joy, they decided to use this magical ability to transform their village into a {adjective3} haven for all.

The news of their adventures spread far and wide, attracting the attention of a curious {noun2} from a distant land. 

This {noun2}, named {get_input('name')}, joined {get_input('name')} and {get_input('name')} on their quest, 

bringing with {get_input('pronoun')} a bag of {get_input('plural_noun')} that possessed {adjective3} qualities.

Together, the trio continued to {verb2} and {verb3} across the magical lands, leaving behind a trail of happiness and wonder. 

They transformed every challenge into an opportunity for growth and every setback into a lesson.

Finally, they returned to their village, where the once dull streets now sparkled with {adjective2} lights and the air was filled with the melody of laughter. 

{get_input('name')}, {get_input('name')}, and {get_input('name')} had not only discovered the power of the {noun3} but also the true magic that lies within the bonds of friendship.

And so, in the heart of their transformed village, {get_input('name')}, {get_input('name')}, and {get_input('name')} lived happily ever after, 

their story becoming a cherished legend passed down from generation to generation.

"""
    
print(user_story)
# Out:
# Once upon a time, in a quaint little village, there lived a beautiful Sherhone named Jimmini Cricket.
#
# She was known for flying with unmatched enthusiasm, spreading joy and laughter to everyone her met.
#
# One sunny day, as they flyed through the Earth IHOP, He encountered a mysterious lovely Shamora.
#
# This Shamora, named him, had the ability to dance with a magical touch. Intrigued, Jimmy decided to dance alongside Jess.
#
# As they danceed together, they stumbled upon an ancient Amiyah hidden in the heart of the McDonalds.
#
# Legend had it that this Amiyah held the key to unlocking long powers. With determination in their hearts,
#
# Sheneka and Athena embarked on a quest to unravel the mysteries of the Amiyah.
#
# Their journey took them through enchanted forests, across vast deserts, and over towering mountains.
#
# Along the way, they encountered a wise old Sherhone who flyed ancient tales of bravery and friendship.
#
# ...
